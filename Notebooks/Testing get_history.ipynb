# %%
from utils_1.goenv import GoEnv, create_env_copy
state = GoEnv('black', 13)
state.reset()
state.print_board()
# Out:
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .

# %%
state.step(1)
state.step(5)
state.step(9)
state.print_board()
# Out:
# . X . . . O . . . X . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . .

# %%
winner = -1 * state.get_winner()
player = -1 if state.get_history()[16][0][0] == 1 else 1
r = winner * player

print (winner, player, r)
# Out:
# -1 -1 1

# %%
print (state.get_winner())
print (state.player_turn())
# Out:
# 1
# -1

# %%
import time
from tqdm import tqdm

start_time = time.time()

num_calls = 400 * 200 * 200
for c in tqdm(range(num_calls)):
    state.get_legal_moves()
print (time.time() - start_time)
# Out:
#   1%|          | 125925/16000000 [00:32<1:07:06, 3942.60it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-8475d1cf108f> in <module>
#       6 num_calls = 400 * 200 * 200
#       7 for c in tqdm(range(num_calls)):
# ----> 8     state.get_legal_moves()
#       9 print (time.time() - start_time)
#
# ~/rl/deepGo/utils_1/goenv.py in get_legal_moves(self, avoid_dumb_passes)
#      91             if not avoid_dumb_passes or move != self.board_size ** 2 or self.test_move(move):
#      92                 final_moves[move] = 1
# ---> 93         if(np.sum(final_moves)==0):
#      94             final_moves[self.board_size**2] = 1
#      95         return final_moves
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~/anaconda3/envs/AlphaGo/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
# ...

# %%
start_time = time.time()

num_calls = 400 * 200 * 200
for c in tqdm(range(num_calls)):
    state.hash_state()
print (time.time() - start_time)
# Out:
# ...
#   1%|          | 99887/16000000 [00:33<1:29:26, 2963.05it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-21216269b678> in <module>
#       3 num_calls = 400 * 200 * 200
#       4 for c in tqdm(range(num_calls)):
# ----> 5     state.hash_state()
#       6 print (time.time() - start_time)
#
# ~/rl/deepGo/utils_1/goenv.py in hash_state(self)
#     157         Unrolled list version of board
#     158         """
# --> 159         return ' '.join( [str(e) for e in self.give_Board().flatten()] ), self.player_turn()
#     160
#     161     def print_board(self):
#
# ~/rl/deepGo/utils_1/goenv.py in give_Board(self)
#     147
#     148     def give_Board(self):
# --> 149         board = self.board.encode()
#     150         act_board = np.zeros(self.board_size**2,dtype = int).reshape(self.board_size,self.board_size)
#     151         act_board[board[0]!=0] = 1
#
# ...
